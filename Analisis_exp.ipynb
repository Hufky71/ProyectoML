# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Carga del Dataset

# %%
df=pd.read_csv('ObesityDataSet_raw_and_data_sinthetic.csv')

# %%
df.sample(5)
# Out:
#             Age  Gender    Height      Weight       CALC FAVC      FCVC  \
# 2067  23.647935  Female  1.681394  114.479459  Sometimes  yes  3.000000
# 1224  22.754646    Male  1.734237   95.000000         no  yes  2.000000
# 2000  18.976968  Female  1.759091  133.903612  Sometimes  yes  3.000000
# 893   25.785925    Male  1.818848   87.032398         no  yes  2.286481
# 598   18.000000    Male  1.706530   51.121749  Sometimes  yes  2.000000
#
#            NCP SCC SMOKE      CH2O family_history_with_overweight       FAF  \
# 2067  3.000000  no    no  2.435978                            yes  0.232742
# 1224  3.000000  no    no  2.287248                            yes  2.669179
# 2000  3.000000  no    no  2.862408                            yes  1.456933
# 893   1.713762  no    no  1.797161                             no  1.658698
# 598   3.000000  no    no  2.000000                            yes  0.000000
#
#            TUE       CAEC                 MTRANS           NObeyesdad
# 2067  0.692608  Sometimes  Public_Transportation     Obesity_Type_III
# 1224  1.237867  Sometimes  Public_Transportation       Obesity_Type_I
# 2000  0.742423  Sometimes  Public_Transportation     Obesity_Type_III
# 893   0.926581  Sometimes             Automobile   Overweight_Level_I
# 598   1.329237  Sometimes  Public_Transportation  Insufficient_Weight

# %%
df.describe()
# Out:
#                Age       Height       Weight         FCVC          NCP  \
# count  2111.000000  2111.000000  2111.000000  2111.000000  2111.000000
# mean     24.312600     1.701677    86.586058     2.419043     2.685628
# std       6.345968     0.093305    26.191172     0.533927     0.778039
# min      14.000000     1.450000    39.000000     1.000000     1.000000
# 25%      19.947192     1.630000    65.473343     2.000000     2.658738
# 50%      22.777890     1.700499    83.000000     2.385502     3.000000
# 75%      26.000000     1.768464   107.430682     3.000000     3.000000
# max      61.000000     1.980000   173.000000     3.000000     4.000000
#
#               CH2O          FAF          TUE
# count  2111.000000  2111.000000  2111.000000
# mean      2.008011     1.010298     0.657866
# std       0.612953     0.850592     0.608927
# min       1.000000     0.000000     0.000000
# 25%       1.584812     0.124505     0.000000
# 50%       2.000000     1.000000     0.625350
# 75%       2.477420     1.666678     1.000000
# max       3.000000     3.000000     2.000000

# %%
df.dtypes
# Out:
# Age                               float64
# Gender                             object
# Height                            float64
# Weight                            float64
# CALC                               object
# FAVC                               object
# FCVC                              float64
# NCP                               float64
# SCC                                object
# SMOKE                              object
# CH2O                              float64
# family_history_with_overweight     object
# FAF                               float64
# TUE                               float64
# CAEC                               object
# MTRANS                             object
# NObeyesdad                         object
# dtype: object

# %%
import seaborn as sns
sns.boxplot(x='Gender', y='Age', data=df)

plt.title('Box plot of Age grouped by Gender')
plt.show()

# %%
# Assuming 'df' is your DataFrame and it has columns 'Weight' and 'Gender'
sns.boxplot(x='Gender', y='Weight', data=df)

plt.title('Box plot of Weight grouped by Gender')
plt.show()
